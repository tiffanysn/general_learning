# %%
import pandas as pd

# %%
# !ls data/
# Out:
# pokemon_data.csv

# %%
df = pd.read_csv('data/pokemon_data.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df['Name'])
df['HP']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
print(df.tail(3))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
print(df[['Name','HP']])
# Out:
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
print(df.iloc[0:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
df.loc[df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name',ascending= False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','HP'],ascending= [1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Total']= df.iloc[ : ,4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
cols=list(df.columns)
df = df[cols[0:4]+ [cols[-1]]+cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Generation  Legendary  Total  HP  \
# 0  1              Bulbasaur  Grass  Poison           1      False    318  45
# 1  2                Ivysaur  Grass  Poison           1      False    405  60
# 2  3               Venusaur  Grass  Poison           1      False    525  80
# 3  3  VenusaurMega Venusaur  Grass  Poison           1      False    625  80
# 4  4             Charmander   Fire     NaN           1      False    309  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.to_csv('modified.csv', index= False)

# %%
df.to_csv('modified.txt',index=False, sep='\t')

# %%
new_df= df.loc[(df['Type 1']=='Grass') & (df['Type 2']== 'Poison') & (df['HP'] > 70)]

# %%
new_df.to_csv('new_df')

# %%
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#      #                   Name Type 1  Type 2  Generation  Legendary  Total  \
# 0    3               Venusaur  Grass  Poison           1      False    525
# 1    3  VenusaurMega Venusaur  Grass  Poison           1      False    625
# 2   45              Vileplume  Grass  Poison           1      False    490
# 3   71             Victreebel  Grass  Poison           1      False    490
# 4  591              Amoonguss  Grass  Poison           5      False    464
#
#     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0   80      82       83      100      100     80
# 1   80     100      123      122      120     80
# 2   75      80       85      110       90     50
# 3   80     105       65      100       70     70
# 4  114      85       70       85       80     30

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Generation  \
# 3      3      VenusaurMega Venusaur     Grass    Poison           1
# 7      6  CharizardMega Charizard X      Fire    Dragon           1
# 8      6  CharizardMega Charizard Y      Fire    Flying           1
# 12     9    BlastoiseMega Blastoise     Water       NaN           1
# 19    15      BeedrillMega Beedrill       Bug    Poison           1
# 23    18        PidgeotMega Pidgeot    Normal    Flying           1
# 71    65      AlakazamMega Alakazam   Psychic       NaN           1
# 87    80        SlowbroMega Slowbro     Water   Psychic           1
# 102   94          GengarMega Gengar     Ghost    Poison           1
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN           1
# 137  127          PinsirMega Pinsir       Bug    Flying           1
# 141  130      GyaradosMega Gyarados     Water      Dark           1
# 154  142  AerodactylMega Aerodactyl      Rock    Flying           1
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Generation  Legendary  Total  \
# 0      1            Bulbasaur    Grass  Poison           1      False    318
# 1      2              Ivysaur    Grass  Poison           1      False    405
# 2      3             Venusaur    Grass  Poison           1      False    525
# 4      4           Charmander     Fire     NaN           1      False    309
# 5      5           Charmeleon     Fire     NaN           1      False    405
# ..   ...                  ...      ...     ...         ...        ...    ...
# 794  718     Zygarde50% Forme   Dragon  Ground           6       True    600
# 795  719              Diancie     Rock   Fairy           6       True    600
# 797  720  HoopaHoopa Confined  Psychic   Ghost           6       True    600
# 798  720   HoopaHoopa Unbound  Psychic    Dark           6       True    680
# 799  721            Volcanion     Fire   Water           6       True    600
#
# ...

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass',regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Generation  Legendary  Total  \
# 0      1              Bulbasaur  Grass  Poison           1      False    318
# 1      2                Ivysaur  Grass  Poison           1      False    405
# 2      3               Venusaur  Grass  Poison           1      False    525
# 3      3  VenusaurMega Venusaur  Grass  Poison           1      False    625
# 4      4             Charmander   Fire     NaN           1      False    309
# ..   ...                    ...    ...     ...         ...        ...    ...
# 735  667                 Litleo   Fire  Normal           6      False    369
# 736  668                 Pyroar   Fire  Normal           6      False    507
# 740  672                 Skiddo  Grass     NaN           6      False    350
# 741  673                 Gogoat  Grass     NaN           6      False    531
# 799  721              Volcanion   Fire   Water           6       True    600
#
# ...

# %%
import re

# %%
df.loc[df['Name'].str.contains('^pi[a:z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Generation  Legendary  \
# 20    16               Pidgey    Normal    Flying           1      False
# 21    17            Pidgeotto    Normal    Flying           1      False
# 22    18              Pidgeot    Normal    Flying           1      False
# 23    18  PidgeotMega Pidgeot    Normal    Flying           1      False
# 30    25              Pikachu  Electric       NaN           1      False
# 136  127               Pinsir       Bug       NaN           1      False
# 137  127    PinsirMega Pinsir       Bug    Flying           1      False
# 186  172                Pichu  Electric       NaN           2      False
# 219  204               Pineco       Bug       NaN           2      False
# 239  221            Piloswine       Ice    Ground           2      False
# 438  393               Piplup     Water       NaN           4      False
# 558  499              Pignite      Fire  Fighting           5      False
# ...

# %%
df.loc[df['Type 1']== 'Fire', 'Type 1']= 'Flammer'
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander  Flammer     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion  Flammer   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.loc[df['Type 1']== 'Flammer', 'Type 1']= 'Fire'
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.loc[df['Type 1']== 'Fire', 'Legendary']= 'True'
df
# Out:
#        #                   Name   Type 1  Type 2  Generation Legendary  Total  \
# 0      1              Bulbasaur    Grass  Poison           1     False    318
# 1      2                Ivysaur    Grass  Poison           1     False    405
# 2      3               Venusaur    Grass  Poison           1     False    525
# 3      3  VenusaurMega Venusaur    Grass  Poison           1     False    625
# 4      4             Charmander     Fire     NaN           1      True    309
# ..   ...                    ...      ...     ...         ...       ...    ...
# 795  719                Diancie     Rock   Fairy           6      True    600
# 796  719    DiancieMega Diancie     Rock   Fairy           6      True    700
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6      True    600
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6      True    680
# 799  721              Volcanion     Fire   Water           6      True    600
#
# ...

# %%
df=pd.read_csv('modified.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.loc[df['Total'] > 500, ['Generation','Legendary']]= 'Test Value'
df
# Out:
#        #                   Name   Type 1  Type 2  Generation   Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1       False
# 1      2                Ivysaur    Grass  Poison           1       False
# 2      3               Venusaur    Grass  Poison  Test Value  Test Value
# 3      3  VenusaurMega Venusaur    Grass  Poison  Test Value  Test Value
# 4      4             Charmander     Fire     NaN           1       False
# ..   ...                    ...      ...     ...         ...         ...
# 795  719                Diancie     Rock   Fairy  Test Value  Test Value
# 796  719    DiancieMega Diancie     Rock   Fairy  Test Value  Test Value
# 797  720    HoopaHoopa Confined  Psychic   Ghost  Test Value  Test Value
# 798  720     HoopaHoopa Unbound  Psychic    Dark  Test Value  Test Value
# 799  721              Volcanion     Fire   Water  Test Value  Test Value
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
pd.read_csv('modified.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Generation   Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1       False
# 1      2                Ivysaur    Grass  Poison           1       False
# 2      3               Venusaur    Grass  Poison  Test Value  Test Value
# 3      3  VenusaurMega Venusaur    Grass  Poison  Test Value  Test Value
# 4      4             Charmander     Fire     NaN           1       False
# ..   ...                    ...      ...     ...         ...         ...
# 795  719                Diancie     Rock   Fairy  Test Value  Test Value
# 796  719    DiancieMega Diancie     Rock   Fairy  Test Value  Test Value
# 797  720    HoopaHoopa Confined  Psychic   Ghost  Test Value  Test Value
# 798  720     HoopaHoopa Unbound  Psychic    Dark  Test Value  Test Value
# 799  721              Volcanion     Fire   Water  Test Value  Test Value
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('HP', ascending= False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# ...

# %%
pd.read_csv('modified.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Generation   Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1       False
# 1      2                Ivysaur    Grass  Poison           1       False
# 2      3               Venusaur    Grass  Poison  Test Value  Test Value
# 3      3  VenusaurMega Venusaur    Grass  Poison  Test Value  Test Value
# 4      4             Charmander     Fire     NaN           1       False
# ..   ...                    ...      ...     ...         ...         ...
# 795  719                Diancie     Rock   Fairy  Test Value  Test Value
# 796  719    DiancieMega Diancie     Rock   Fairy  Test Value  Test Value
# 797  720    HoopaHoopa Confined  Psychic   Ghost  Test Value  Test Value
# 798  720     HoopaHoopa Unbound  Psychic    Dark  Test Value  Test Value
# 799  721              Volcanion     Fire   Water  Test Value  Test Value
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Type 1
# Bug       23080  26146  3925    4897     4880     3717     4471   4256
# Dark      14302  13818  2071    2740     2177     2314     2155   2361
# Dragon    15180  17617  2666    3588     2764     3099     2843   2657
# Electric  15994  19510  2631    3040     2917     3961     3243   3718
# Fairy      7642   7024  1260    1046     1117     1335     1440    826
# Fighting   9824  11244  1886    2613     1780     1434     1747   1784
# Fire      17025  23820  3635    4408     3524     4627     3755   3871
# Flying     2711   1940   283     315      265      377      290    410
# Ghost     15568  14066  2062    2361     2598     2539     2447   2059
# Grass     24141  29480  4709    5125     4956     5425     4930   4335
# Ground    11401  14000  2361    3064     2715     1807     2008   2045
# Ice       10165  10403  1728    1746     1714     1861     1831   1523
# ...

# %%
pd.read_csv('modified.csv')
df['count']= 1
df
# Out:
#        #                   Name   Type 1  Type 2  Generation   Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1       False
# 1      2                Ivysaur    Grass  Poison           1       False
# 2      3               Venusaur    Grass  Poison  Test Value  Test Value
# 3      3  VenusaurMega Venusaur    Grass  Poison  Test Value  Test Value
# 4      4             Charmander     Fire     NaN           1       False
# ..   ...                    ...      ...     ...         ...         ...
# 795  719                Diancie     Rock   Fairy  Test Value  Test Value
# 796  719    DiancieMega Diancie     Rock   Fairy  Test Value  Test Value
# 797  720    HoopaHoopa Confined  Psychic   Ghost  Test Value  Test Value
# 798  720     HoopaHoopa Unbound  Psychic    Dark  Test Value  Test Value
# 799  721              Volcanion     Fire   Water  Test Value  Test Value
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  count
# ...

# %%
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
for df in pd.read_csv('modified.csv',chunksize=5):
    print("CHUNK DF")
    print(df)
# Out:
# CHUNK DF
#    #                   Name Type 1  Type 2  Generation  Legendary  Total  HP  \
# 0  1              Bulbasaur  Grass  Poison           1      False    318  45
# 1  2                Ivysaur  Grass  Poison           1      False    405  60
# 2  3               Venusaur  Grass  Poison           1      False    525  80
# 3  3  VenusaurMega Venusaur  Grass  Poison           1      False    625  80
# 4  4             Charmander   Fire     NaN           1      False    309  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65
# CHUNK DF
#    #                       Name Type 1  Type 2  Generation  Legendary  Total  \
# 5  5                 Charmeleon   Fire     NaN           1      False    405
# ...

# %%
df = pd.read_csv('modified.csv')
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.shape
# Out:
# (5, 13)

# %%
df = pd.read_csv('modified.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
new_df= df.loc[(df['Generation']== 1)& (df['Type 1']== 'Grass') ]
new_df
#new_df.groupby(['Type 1']).mean()#.sort_values('HP', ascending= False)
# Out:
#        #                   Name Type 1   Type 2  Generation  Legendary  Total  \
# 0      1              Bulbasaur  Grass   Poison           1      False    318
# 1      2                Ivysaur  Grass   Poison           1      False    405
# 2      3               Venusaur  Grass   Poison           1      False    525
# 3      3  VenusaurMega Venusaur  Grass   Poison           1      False    625
# 48    43                 Oddish  Grass   Poison           1      False    320
# 49    44                  Gloom  Grass   Poison           1      False    395
# 50    45              Vileplume  Grass   Poison           1      False    490
# 75    69             Bellsprout  Grass   Poison           1      False    300
# 76    70             Weepinbell  Grass   Poison           1      False    390
# 77    71             Victreebel  Grass   Poison           1      False    490
# 110  102              Exeggcute  Grass  Psychic           1      False    325
# ...

# %%
df['Generation']== 1
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Generation, Length: 800, dtype: bool

# %%
df.sort_values(['HP'],ascending=False)
# Out:
#        #       Name   Type 1 Type 2  Generation  Legendary  Total   HP  \
# 261  242    Blissey   Normal    NaN           2      False    540  255
# 121  113    Chansey   Normal    NaN           1      False    450  250
# 217  202  Wobbuffet  Psychic    NaN           2      False    405  190
# 351  321    Wailord    Water    NaN           3      False    500  170
# 655  594  Alomomola    Water    NaN           5      False    470  165
# ..   ...        ...      ...    ...         ...        ...    ...  ...
# 139  129   Magikarp    Water    NaN           1      False    200   20
# 381  349     Feebas    Water    NaN           3      False    200   20
# 388  355    Duskull    Ghost    NaN           3      False    295   20
# 55    50    Diglett   Ground    NaN           1      False    265   10
# 316  292   Shedinja      Bug  Ghost           3      False    236    1
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed
# 261      10       10       75      135     55
# ...

# %%
# !ls data/
# Out:
# pokemon_data.csv

# %%
df = pd.read_csv('data/pokemon_data.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df['Type 2']=='Poison']
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 16    13                 Weedle    Bug  Poison   40      35       30       20
# 17    14                 Kakuna    Bug  Poison   45      25       50       25
# 18    15               Beedrill    Bug  Poison   65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison   65     150       40       15
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# ...

# %%
df.pivot_table(index= 'Type 1',columns='Generation',values='HP', aggfunc='min')
# Out:
# Generation     1     2     3     4     5     6
# Type 1
# Bug         35.0  20.0   1.0  30.0  30.0  38.0
# Dark         NaN  45.0  35.0  70.0  40.0  53.0
# Dragon      41.0   NaN  45.0  58.0  46.0  45.0
# Electric    25.0  20.0  40.0  45.0  35.0  44.0
# Fairy       70.0  35.0   NaN  85.0   NaN  44.0
# Fighting    40.0  35.0  30.0  40.0  45.0  67.0
# Fire        38.0  39.0  45.0  44.0  50.0  40.0
# Flying       NaN   NaN   NaN   NaN  79.0  40.0
# Ghost       30.0  60.0  20.0  45.0  38.0  43.0
# Grass       45.0  30.0  40.0  40.0  40.0  56.0
# Ground      10.0  65.0  40.0  68.0  50.0   NaN
# Ice         65.0  45.0  50.0  65.0  36.0  55.0
# Normal      30.0  35.0  38.0  40.0  45.0  38.0
# Poison      35.0  85.0  70.0  40.0  50.0  50.0
# Psychic     25.0  40.0  28.0  20.0  45.0  62.0
# Rock        30.0  50.0  30.0  30.0  55.0  42.0
# Steel        NaN  65.0  40.0  57.0  40.0  45.0
# Water       20.0  35.0  20.0  45.0  50.0  41.0

# %%
df.pivot(index= 'Name',columns='Generation',values='HP')
# Out:
# Generation                  1   2     3     4     5      6
# Name
# Abomasnow                 NaN NaN   NaN  90.0   NaN    NaN
# AbomasnowMega Abomasnow   NaN NaN   NaN  90.0   NaN    NaN
# Abra                     25.0 NaN   NaN   NaN   NaN    NaN
# Absol                     NaN NaN  65.0   NaN   NaN    NaN
# AbsolMega Absol           NaN NaN  65.0   NaN   NaN    NaN
# ...                       ...  ..   ...   ...   ...    ...
# Zoroark                   NaN NaN   NaN   NaN  60.0    NaN
# Zorua                     NaN NaN   NaN   NaN  40.0    NaN
# Zubat                    40.0 NaN   NaN   NaN   NaN    NaN
# Zweilous                  NaN NaN   NaN   NaN  72.0    NaN
# Zygarde50% Forme          NaN NaN   NaN   NaN   NaN  108.0
#
# [800 rows x 6 columns]

# %%
df.pivot_table(index='Type 1',columns='Legendary',values=['Attack','HP'],aggfunc='mean').dropna()
# Out:
#                Attack                     HP
# Legendary       False       True       False       True
# Type 1
# Dark        86.862069  110.500000  64.655172   98.000000
# Dragon     103.400000  126.666667  72.650000  101.083333
# Electric    66.125000   98.750000  57.325000   84.500000
# Fairy       57.187500  131.000000  70.875000  126.000000
# Fire        82.191489  109.000000  67.085106   96.400000
# Flying      50.000000  107.500000  62.500000   79.000000
# Ghost       71.366667  110.000000  58.733333  150.000000
# Grass       72.119403   97.666667  65.940299   97.000000
# Ground      88.000000  150.000000  70.821429   94.500000
# Ice         73.227273   67.500000  70.818182   85.000000
# Normal      72.083333  140.000000  76.489583  115.000000
# Psychic     54.953488  122.142857  67.720930   79.571429
# Rock        89.925000  122.250000  65.125000   67.750000
# Steel       92.086957   96.250000  60.434783   92.750000
# Water       72.777778  111.250000  71.120370   97.500000
